# %% [markdown]
# # Librerías

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %% [markdown]
# # Importar datos

# %%
track_features = pd.read_csv('./data/tf_mini.csv', index_col=0)
sessions = pd.read_csv('./data/log_mini.csv')

# %% [markdown]
# # Renombrar columnas

# %%
sessions = sessions.rename(columns={'session_id': 'user_id', 'track_id_clean': 'track_id'})
track_features = track_features.rename(columns={'release_year': 'year'})

# %% [markdown]
# # Eliminar columnas

# %% [markdown]
# De `track_features` conservaremos solamente las columnas que puedan ser obtenidas desde la API de Spotify:

# %%
track_features = track_features[[
    'duration', 'year', 'us_popularity_estimate', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'key',
    'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'
]]
print('Dataset Track Features, sin columnas no obtenibles de la API de Spotify:')
print('- Filas:', track_features.shape[0])
print('- Columnas:', track_features.shape[1])
print('- Datos nulos:', track_features.isna().sum().sum())
display(track_features.head(3))
# Out:
# Dataset Track Features, sin columnas no obtenibles de la API de Spotify:
# - Filas: 50704
# - Columnas: 15
# - Datos nulos: 0
#                                           duration  year  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  109.706673  1950
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  187.693329  1950
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  160.839996  1951
#
#                                         us_popularity_estimate  acousticness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d               99.975414      0.458040
# t_67965da0-132b-4b1e-8a69-0ef99b32287c               99.969430      0.916272
# t_0614ecd3-a7d5-40a1-816e-156d5872a467               99.602549      0.812884
#
#                                         danceability    energy  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      0.399767  0.817709
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      0.491235  0.154258
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      0.491625  0.358813
#
#                                         instrumentalness  key  liveness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      3.254327e-06    0  0.132124
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      8.344854e-12    0  0.163281
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      2.927475e-10    0  0.090115
#
#                                         loudness   mode  speechiness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d   -11.238  major     0.079985
# t_67965da0-132b-4b1e-8a69-0ef99b32287c   -13.706  major     0.083877
# t_0614ecd3-a7d5-40a1-816e-156d5872a467   -10.522  minor     0.038777
#
#                                              tempo  time_signature   valence
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  166.287003               4  0.935512
# t_67965da0-132b-4b1e-8a69-0ef99b32287c   95.261002               3  0.359675
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  105.185997               4  0.726769

# %% [markdown]
# De `sessions` solo queremos las interacciones usuario-ítem, así que conservaremos solo `session_id` y `track_id`:

# %%
sessions = sessions[['user_id', 'track_id']]
print('Dataset Sessions:')
print('- Filas:', sessions.shape[0])
print('- Columnas:', sessions.shape[1])
print('- Datos nulos:', sessions.isna().sum().sum())
display(sessions.head(3))
# Out:
# Dataset Sessions:
# - Filas: 167880
# - Columnas: 2
# - Datos nulos: 0
#                                   user_id  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 2  0_00006f66-33e5-4de7-a324-2d18e439fc1e
#
#                                  track_id
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 1  t_9099cd7b-c238-47b7-9381-f23f2c1d1043
# 2  t_fc5df5ba-5396-49a7-8b29-35d0d28249e0

# %% [markdown]
# # Normalizar columnas

# %%
track_features.loc[:, 'duration'] = track_features.loc[:, 'duration'] / max(track_features['duration'])
track_features.loc[:, 'year'] = track_features.loc[:, 'year'] / 2022
track_features.loc[:, 'us_popularity_estimate'] = track_features.loc[:, 'us_popularity_estimate'] / 100
track_features.loc[:, 'tempo'] = track_features.loc[:, 'tempo'] / max(track_features['tempo'])
track_features.loc[:, 'loudness'] = track_features.loc[:, 'loudness'] / min(track_features['loudness'])
track_features.head(3)
# Out:
#                                         duration      year  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  0.061365  0.964392
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.104988  0.964392
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.089967  0.964886
#
#                                         us_popularity_estimate  acousticness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d                0.999754      0.458040
# t_67965da0-132b-4b1e-8a69-0ef99b32287c                0.999694      0.916272
# t_0614ecd3-a7d5-40a1-816e-156d5872a467                0.996025      0.812884
#
#                                         danceability    energy  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      0.399767  0.817709
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      0.491235  0.154258
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      0.491625  0.358813
#
#                                         instrumentalness  key  liveness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      3.254327e-06    0  0.132124
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      8.344854e-12    0  0.163281
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      2.927475e-10    0  0.090115
#
#                                         loudness   mode  speechiness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  0.187300  major     0.079985
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.228433  major     0.083877
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.175367  minor     0.038777
#
#                                            tempo  time_signature   valence
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  0.760082               4  0.935512
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.435429               3  0.359675
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.480795               4  0.726769

# %% [markdown]
# # Transformar columnas categóricas a columnas numéricas

# %%
track_features.loc[:, 'mode'] = LabelEncoder().fit_transform(track_features.loc[:, 'mode'])
track_features.head(3)
# Out:
#                                         duration      year  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  0.061365  0.964392
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.104988  0.964392
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.089967  0.964886
#
#                                         us_popularity_estimate  acousticness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d                0.999754      0.458040
# t_67965da0-132b-4b1e-8a69-0ef99b32287c                0.999694      0.916272
# t_0614ecd3-a7d5-40a1-816e-156d5872a467                0.996025      0.812884
#
#                                         danceability    energy  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      0.399767  0.817709
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      0.491235  0.154258
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      0.491625  0.358813
#
#                                         instrumentalness  key  liveness  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d      3.254327e-06    0  0.132124
# t_67965da0-132b-4b1e-8a69-0ef99b32287c      8.344854e-12    0  0.163281
# t_0614ecd3-a7d5-40a1-816e-156d5872a467      2.927475e-10    0  0.090115
#
#                                         loudness  mode  speechiness     tempo  \
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d  0.187300     0     0.079985  0.760082
# t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.228433     0     0.083877  0.435429
# t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.175367     1     0.038777  0.480795
#
#                                         time_signature   valence
# track_id
# t_a540e552-16d4-42f8-a185-232bd650ea7d               4  0.935512
# t_67965da0-132b-4b1e-8a69-0ef99b32287c               3  0.359675
# t_0614ecd3-a7d5-40a1-816e-156d5872a467               4  0.726769

# %% [markdown]
# # Guardar datos procesados

# %%
track_features.to_csv('./data/processed_track_features.csv')
sessions.to_csv('./data/processed_sessions.csv', index=False)
