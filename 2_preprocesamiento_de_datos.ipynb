# %% [markdown]
# # Librerías

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %% [markdown]
# # Importar datos

# %%
track_features = pd.read_csv('./data/tf_mini.csv')
sessions = pd.read_csv('./data/log_mini.csv')

# %% [markdown]
# # Eliminar columnas

# %% [markdown]
# De `track_features` conservaremos solamente las columnas que puedan ser obtenidas desde la API de Spotify:

# %%
track_features = track_features[[
    'track_id', 'duration', 'release_year', 'us_popularity_estimate', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'key',
    'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'
]]
print('Dataset Track Features, sin columnas no obtenibles de la API de Spotify:')
print('- Filas:', track_features.shape[0])
print('- Columnas:', track_features.shape[1])
print('- Datos nulos:', track_features.isna().sum().sum())
display(track_features.head(3))
# Out:
# Dataset Track Features, sin columnas no obtenibles de la API de Spotify:
# - Filas: 50704
# - Columnas: 16
# - Datos nulos: 0
#                                  track_id    duration  release_year  \
# 0  t_a540e552-16d4-42f8-a185-232bd650ea7d  109.706673          1950
# 1  t_67965da0-132b-4b1e-8a69-0ef99b32287c  187.693329          1950
# 2  t_0614ecd3-a7d5-40a1-816e-156d5872a467  160.839996          1951
#
#    us_popularity_estimate  acousticness  danceability    energy  \
# 0               99.975414      0.458040      0.399767  0.817709
# 1               99.969430      0.916272      0.491235  0.154258
# 2               99.602549      0.812884      0.491625  0.358813
#
#    instrumentalness  key  liveness  loudness   mode  speechiness       tempo  \
# 0      3.254327e-06    0  0.132124   -11.238  major     0.079985  166.287003
# 1      8.344854e-12    0  0.163281   -13.706  major     0.083877   95.261002
# 2      2.927475e-10    0  0.090115   -10.522  minor     0.038777  105.185997
#
#    time_signature   valence
# 0               4  0.935512
# 1               3  0.359675
# 2               4  0.726769

# %% [markdown]
# De `sessions` quitaremos todas las columnas asociadas a contexto:

# %%
sessions = sessions.iloc[:, 0:8]
print('Dataset Sessions:')
print('- Filas:', sessions.shape[0])
print('- Columnas:', sessions.shape[1])
print('- Datos nulos:', sessions.isna().sum().sum())
display(sessions.head(3))
# Out:
# Dataset Sessions:
# - Filas: 167880
# - Columnas: 8
# - Datos nulos: 0
#                                session_id  session_position  session_length  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1              20
# 1  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2              20
# 2  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3              20
#
#                            track_id_clean  skip_1  skip_2  skip_3  not_skipped
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False   False         True
# 1  t_9099cd7b-c238-47b7-9381-f23f2c1d1043   False   False   False         True
# 2  t_fc5df5ba-5396-49a7-8b29-35d0d28249e0   False   False   False         True

# %% [markdown]
# # Normalizar columnas

# %%
track_features.loc[:, 'duration'] = track_features.loc[:, 'duration'] / max(track_features['duration'])
track_features.loc[:, 'release_year'] = track_features.loc[:, 'release_year'] / 2022
track_features.loc[:, 'us_popularity_estimate'] = track_features.loc[:, 'us_popularity_estimate'] / 100
track_features.loc[:, 'tempo'] = track_features.loc[:, 'tempo'] / max(track_features['tempo'])
track_features.loc[:, 'loudness'] = track_features.loc[:, 'loudness'] / min(track_features['loudness'])
track_features.head(3)
# Out:
#                                  track_id  duration  release_year  \
# 0  t_a540e552-16d4-42f8-a185-232bd650ea7d  0.061365      0.964392
# 1  t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.104988      0.964392
# 2  t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.089967      0.964886
#
#    us_popularity_estimate  acousticness  danceability    energy  \
# 0                0.999754      0.458040      0.399767  0.817709
# 1                0.999694      0.916272      0.491235  0.154258
# 2                0.996025      0.812884      0.491625  0.358813
#
#    instrumentalness  key  liveness  loudness   mode  speechiness     tempo  \
# 0      3.254327e-06    0  0.132124  0.187300  major     0.079985  0.760082
# 1      8.344854e-12    0  0.163281  0.228433  major     0.083877  0.435429
# 2      2.927475e-10    0  0.090115  0.175367  minor     0.038777  0.480795
#
#    time_signature   valence
# 0               4  0.935512
# 1               3  0.359675
# 2               4  0.726769

# %% [markdown]
# # Transformar columnas categóricas a columnas numéricas

# %%
track_features.loc[:, 'mode'] = LabelEncoder().fit_transform(track_features.loc[:, 'mode'])
track_features.head(3)
# Out:
#                                  track_id  duration  release_year  \
# 0  t_a540e552-16d4-42f8-a185-232bd650ea7d  0.061365      0.964392
# 1  t_67965da0-132b-4b1e-8a69-0ef99b32287c  0.104988      0.964392
# 2  t_0614ecd3-a7d5-40a1-816e-156d5872a467  0.089967      0.964886
#
#    us_popularity_estimate  acousticness  danceability    energy  \
# 0                0.999754      0.458040      0.399767  0.817709
# 1                0.999694      0.916272      0.491235  0.154258
# 2                0.996025      0.812884      0.491625  0.358813
#
#    instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 0      3.254327e-06    0  0.132124  0.187300     0     0.079985  0.760082
# 1      8.344854e-12    0  0.163281  0.228433     0     0.083877  0.435429
# 2      2.927475e-10    0  0.090115  0.175367     1     0.038777  0.480795
#
#    time_signature   valence
# 0               4  0.935512
# 1               3  0.359675
# 2               4  0.726769

# %% [markdown]
# # Guardar datos procesados

# %%
track_features.to_csv('./data/track_features.csv')
sessions.to_csv('./data/sessions.csv')
